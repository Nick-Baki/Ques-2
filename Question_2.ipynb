# %%
Room_cost=240000
student_number=3
Each_Student_payment=Roon_cost/student_number
print("Room_Cost: ",Room_cost,"RWF")
print("Student_Number: ",student_number)
print("Each_Student_Payment: ",Each_Student_payment,"RWF")
# Out:
# Room_Cost:  240000 RWF
# Student_Number:  3
# Each_Student_Payment:  80000.0 RWF
